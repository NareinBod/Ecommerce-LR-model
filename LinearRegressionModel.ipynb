# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df = pd.read_csv('ecommerce.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.info()
#we'll only use columns from 3 to 7
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
plt.scatter(x='Avg. Session Length', y='Yearly Amount Spent', data=df)
plt.title('Avg Session length vs Yearly amount spent')
plt.xlabel('Avg Session length')
plt.ylabel('Yearly Amount spent')
# Out:
# Text(0, 0.5, 'Yearly Amount spent')

# %%
plt.scatter(x='Time on App', y='Yearly Amount Spent', data=df)
plt.title('Time on App vs Yearly amount spent')
plt.xlabel('Time on App')
plt.ylabel('Yearly Amount spent')
# Out:
# Text(0, 0.5, 'Yearly Amount spent')

# %%
plt.scatter(x='Time on Website', y='Yearly Amount Spent', data=df)
plt.title('Time on Website vs Yearly amount spent')
plt.xlabel('Time on Website')
plt.ylabel('Yearly Amount spent')
# Out:
# Text(0, 0.5, 'Yearly Amount spent')

# %%
plt.scatter(x='Length of Membership', y='Yearly Amount Spent', data=df)
plt.title('Length of Membership vs Yearly amount spent')
plt.xlabel('Length of Membership')
plt.ylabel('Yearly Amount spent')
# Out:
# Text(0, 0.5, 'Yearly Amount spent')

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
X = df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']]
y = df['Yearly Amount Spent']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state= 42)

# %%
X_train
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 5              33.871038    12.026925        34.476878              5.493507
# 116            33.925795    12.011022        36.701052              2.753424
# 45             34.555768    12.170525        39.131097              3.663105
# 16             32.125387    11.733862        34.894093              3.136133
# 462            33.503810    11.233415        37.211153              2.320550
# ..                   ...          ...              ...                   ...
# 106            32.291756    12.190474        36.152462              3.781823
# 270            34.006489    12.956277        38.655095              3.275734
# 348            31.812483    10.886921        34.897828              3.128639
# 435            32.259973    14.132893        37.023479              3.762070
# 102            32.425697    11.448902        37.580190              2.586968
#
#      Yearly Amount Spent
# ...

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 361            32.077590    10.347877        39.045156              3.434560
# 73             32.808698    12.817113        37.031539              3.851579
# 374            31.447446    10.101632        38.043453              4.238296
# 155            32.449522    13.457725        37.238806              2.941411
# 104            31.389585    10.994224        38.074452              3.428860
# ..                   ...          ...              ...                   ...
# 266            34.555283    11.777772        37.979827              3.784273
# 23             32.903251    11.657576        36.772604              3.919302
# 222            34.334865    11.109456        38.585855              3.892891
# 261            32.550527    13.041245        36.655208              3.456234
# 426            31.425227    13.271475        37.239847              4.022103
#
#      Yearly Amount Spent
# ...

# %%
y_train
# Out:
# 5      637.102448
# 116    479.231093
# 45     549.860590
# 16     457.847696
# 462    397.420584
#           ...
# 106    494.551861
# 270    540.995739
# 348    392.810345
# 435    571.216005
# 102    420.737673
# Name: Yearly Amount Spent, Length: 350, dtype: float64

# %%
#training the model
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#w values - f(x) = w1x1 + w2x2 + w3x3 ..... wnxn
lm.coef_
# Out:
# array([-2.55953002e-14,  1.19904087e-14, -3.76489204e-15, -3.30534211e-14,
#         1.00000000e+00])

# %%
#After we fit the model we predict now with test values

# %%
predictions = lm.predict(X_test)
predictions
# Out:
# array([401.03313522, 534.7771881 , 418.6027421 , 503.97837905,
#        410.06961106, 557.60826205, 538.94197453, 514.33655827,
#        408.62018783, 475.01540709, 427.1993849 , 434.02169975,
#        411.18696357, 533.51493526, 447.3690272 , 407.54216801,
#        573.84743772, 497.5866713 , 466.42119882, 467.80092437,
#        510.40138845, 510.50147847, 511.97985999, 640.5840619 ,
#        444.2859075 , 502.77107457, 551.62014548, 548.51852928,
#        390.10327297, 330.59444603, 535.32161009, 478.60091594,
#        499.14015245, 298.76200786, 487.54750487, 498.63559849,
#        512.16586639, 444.96655165, 468.6684656 , 483.15972078,
#        474.53232944, 439.07476674, 515.50247966, 485.92313052,
#        491.07322368, 544.77986372, 587.95105397, 522.33740461,
#        275.91842065, 436.51560573, 418.1500811 , 493.71919298,
#        573.30622226, 608.27181662, 545.94549214, 483.67330802,
#        424.18549429, 452.31567548, 568.71757593, 488.78606109,
# ...

# %%
#we plot the data with real values to see how close they are 
plt.scatter(predictions, y_test)
plt.xlabel('predictions')
plt.ylabel('y-test')
plt.title('Evaluation of our linear regression model')
# Out:
# Text(0.5, 1.0, 'Evaluation of our linear regression model')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
#We are looking at the cost function
print('Mean Absolute error: ', mean_absolute_error(y_test, predictions))
print('Mean Squared error: ', mean_squared_error(y_test, predictions))
print('Root Mean Squared error: ', math.sqrt(mean_absolute_error(y_test, predictions)))
# Out:
# Mean Absolute error:  3.524291969370097e-14
# Mean Squared error:  3.0803861352886188e-27
# Root Mean Squared error:  1.877309769156411e-07

# %%
#The above data shows the error is very less meaning the model fits very well

# %%
residuals = y_test - predictions
residuals
# Out:
# 361    5.684342e-14
# 73     0.000000e+00
# 374    5.684342e-14
# 155   -5.684342e-14
# 104    0.000000e+00
#            ...
# 266    0.000000e+00
# 23     0.000000e+00
# 222    5.684342e-14
# 261    0.000000e+00
# 426   -1.136868e-13
# Name: Yearly Amount Spent, Length: 150, dtype: float64

# %%
plt.hist(residuals, bins=30)
plt.show()

# %%
import pylab
import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot= pylab)
pylab.show()
